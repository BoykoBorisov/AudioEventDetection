# %%
import csv
import subprocess
import utils

from multiprocessing import Pool
from os.path import exists

# %%
blacklist = set(["/m/09x0r", "/m/04rlf"])
dest = "output_bal_train"

def is_blacklist_entry(entry):
  for label in entry:
    if label not in blacklist:
      return False
  return True

def download_file(csv_row):
  cmd = "ffmpeg -hide_banner -loglevel error -ss {start} -t 10 -i $(youtube-dl -g -f 'best' \"https://youtube.com/watch?v={id}\") -ar {fs} -- \"{dest}/{id}_{start}.wav\""
  cmd = cmd.format(
    start = str(csv_row[1].strip().strip(",")), 
    id = csv_row[0].strip(","), 
    dest = dest, 
    fs = str(16000))
  # print(cmd)
  # subprocess.call("youtube-dl", shell = True)
  subprocess.call(cmd, shell=True)

def download_dataset(): 
  with open("/home/jupyter/ThirdYearProject/datasets/Audioset/balanced_train_segments.csv") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter = " ")
    if __name__ == '__main__':
      with Pool(processes=8) as pool:
        pool.map(utils.download_file_if_not_blacklised, csv_reader)
    
def generate_blacklist_csv():
   with open("unbalanced_train_segments_flagged.csv") as csv_file:
    with open("unbalanced_train_segments_flagged_2.csv", "w") as flagged_csv_file:
      reader = csv.reader(csv_file, delimiter = " ")
      writer = csv.writer(flagged_csv_file, delimiter = " ")
      for row in reader:
        path = "{dest}/{id}_{start}.wav".format(start = str(row[1].strip().strip(",")), id = row[0].strip(","), dest = dest)
        if (exists(path)):
          new_row = []
          new_row += row
          new_row += ["downloaded"]
          writer.writerow(new_row)
        else:
          writer.writerow(row)

# %%
# with open("unbalanced_train_segments.csv") as csv_file:
#   csv_reader = csv.reader(csv_file, delimiter = " ")
#   for csv_row in csv_reader:
#     print(exists("{dest}/{id}_{start}.wav".format(start = str(csv_row[1].strip().strip(",")), id = csv_row[0].strip(","), dest = dest)))

# %%
generate_blacklist_csv()

# %%
download_dataset()
# Out:
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by ユニバーサルミュージック合同会社
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Could not send HEAD request to https://youtube.com/watch?v=#: HTTP Error 429: Too Many Requests
# ERROR: Unable to download webpage: HTTP Error 429: Too Many Requests (caused by <HTTPError 429: 'Too Many Requests'>); please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; type  youtube-dl -U  to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# Invalid duration specification for ss: Segments
# ERROR: Private video
# Sign in if you've been granted access to this video
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# WARNING: Could not send HEAD request to https://youtube.com/watch?v=#: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Unable to download webpage: HTTP Error 429: Too Many Requests (caused by <HTTPError 429: 'Too Many Requests'>); please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; type  youtube-dl -U  to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# Invalid duration specification for ss: num_ytids=22160
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by andrewsketches
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from KBS Media, who has blocked it on copyright grounds.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Could not send HEAD request to https://youtube.com/watch?v=#: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Unable to download webpage: HTTP Error 429: Too Many Requests (caused by <HTTPError 429: 'Too Many Requests'>); please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; type  youtube-dl -U  to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# Invalid duration specification for ss: YTID
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by FujiTV
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: requested format not available
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available due to a privacy claim by a third party
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from Disney, who has blocked it in your country on copyright grounds
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: This video has been removed for violating YouTube's policy on violent or graphic content
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from NBC Universal, who has blocked it in your country on copyright grounds
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by ABS-CBN Corporation
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR: Private video
# Sign in if you've been granted access to this video
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from BandaiChannel, who has blocked it on copyright grounds.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by Aurio Corrá Oficial
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is not available
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from SME, who has blocked it in your country on copyright grounds
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: This video has been removed for violating YouTube's Community Guidelines
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Private video
# Sign in if you've been granted access to this video
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# This video contains content from Moby Group, who has blocked it on copyright grounds.
# -ar: No such file or directory
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# ERROR: Video unavailable
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
# -ar: No such file or directory
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# -ar: No such file or directory
# -ar: No such file or directory
# -ar: No such file or directory
